# %% [markdown]
# ### **Assignment 4: Python Basics and Data Structures**

# %% [markdown]
# **1.** Write a function that takes a string and returns a dictionary with the frequency of each vowel.
# **Example:**
# **Input:** `"Programming in Python"`
# **Output:** `{'o': 2, 'a': 1, 'i': 2}`
#
# ---

# %% [markdown]
# **2.** Check if a given string is a palindrome (ignoring case and spaces).
# **Example:**
# **Input:** `"A man a plan a canal Panama"`
# **Output:** `True`
#
# ---

# %% [markdown]
# **3.** Given a list of integers, return a new list where each element is the sum of itself and its next element. Last element remains unchanged.
# **Example:**
# **Input:** `[1, 2, 3, 4]`
# **Output:** `[3, 5, 7, 4]`
#
# ---

# %% [markdown]
# **4.** Write a function that removes all occurrences of a specific element from a list without using `remove()`.
# **Example:**
# **Input:** `([1, 2, 3, 2, 4], 2)`
# **Output:** `[1, 3, 4]`
#
# ---

# %% [markdown]
# **5.** Create a program to count the number of unique elements in a list using sets.
# **Example:**
# **Input:** `[1, 2, 2, 3, 4, 4, 4]`
# **Output:** `4`
#
# ---

# %% [markdown]
# **6.** Given two tuples, write a program to concatenate them and remove duplicates.
# **Example:**
# **Input:** `(1, 2, 3), (2, 3, 4)`
# **Output:** `(1, 2, 3, 4)` *(order may vary)*
#
# ---

# %% [markdown]
# **7.** Write a function that takes a string and returns the most frequent character (excluding spaces).
# **Example:**
# **Input:** `"hello world"`
# **Output:** `'l'`
#
# ---

# %% [markdown]
# **8.** Take two lists and return a list of elements that are common, without using loops (use set operations).
# **Example:**
# **Input:** `[1, 2, 3], [2, 3, 4]`
# **Output:** `[2, 3]` *(order may vary)*
#
# ---

# %% [markdown]
# **9.** Write a function that takes a string and returns `True` if all characters are unique, else `False`.
# **Example:**
# **Input:** `"python"`
# **Output:** `True`
#
# ---

# %% [markdown]
# **10.** Given a tuple of numbers, return the maximum product of any two distinct numbers.
# **Example:**
# **Input:** `(1, 3, -4, -6, 7)`
# **Output:** `24`
#
# ---
